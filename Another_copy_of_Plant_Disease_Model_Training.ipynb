# %% [markdown]
# <a href="https://colab.research.google.com/github/Trisha11Chatterjee/-Elliptic-Curve-Cryptography-ECC-/blob/main/Another_copy_of_Plant_Disease_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O "dataset.zip" "https://data.mendeley.com/public-files/datasets/tywbtsjrjv/files/b4e3a32f-c0bd-4060-81e9-6144231f2520/file_downloaded"
# Out:
# --2026-03-09 14:25:36--  https://data.mendeley.com/public-files/datasets/tywbtsjrjv/files/b4e3a32f-c0bd-4060-81e9-6144231f2520/file_downloaded
# Resolving data.mendeley.com (data.mendeley.com)... 162.159.130.86, 162.159.133.86
# Connecting to data.mendeley.com (data.mendeley.com)|162.159.130.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/349ac012-2948-4172-bbba-3bf8f76596fd [following]
# --2026-03-09 14:25:37--  https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/349ac012-2948-4172-bbba-3bf8f76596fd
# Resolving prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)... 3.5.66.5, 52.92.34.50, 3.5.72.88, ...
# Connecting to prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)|3.5.66.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 949267727 (905M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 905.29M  12.9MB/s    in 73s
#
# 2026-03-09 14:26:51 (12.4 MB/s) - ‘dataset.zip’ saved [949267727/949267727]

# %%
# !unzip /content/dataset.zip
# Out:
# Archive:  /content/dataset.zip
#    creating: Plant_leave_diseases_dataset_with_augmentation/
#    creating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (1).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (10).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (100).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (1000).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (101).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (102).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (103).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (104).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (105).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (106).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (107).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (108).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (109).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (11).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (110).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (111).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (112).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (113).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (114).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (115).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (116).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (117).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (118).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (119).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (12).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (120).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (121).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (122).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (123).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (124).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (125).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (126).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (127).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (128).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (129).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (13).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (130).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (131).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (132).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (133).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (134).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (135).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (136).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (137).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (138).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (139).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (14).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (140).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (141).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (142).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (143).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (144).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (145).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (146).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (147).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (148).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (149).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (15).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (150).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (151).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (152).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (153).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (154).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (155).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (156).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (157).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (158).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (159).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (16).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (160).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (161).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (162).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (163).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (164).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (165).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (166).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (167).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (168).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (169).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (17).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (170).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (171).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (172).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (173).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (174).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (175).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (176).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (177).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (178).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (179).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (18).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (180).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (181).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (182).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (183).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (184).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (185).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (186).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (187).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (188).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (189).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (19).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (190).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (191).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (192).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (193).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (194).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (195).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (196).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (197).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (198).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (199).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (2).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (20).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (200).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (201).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (202).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (203).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (204).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (205).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (206).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (207).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (208).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (209).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (21).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (210).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (211).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (212).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (213).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (214).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (215).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (216).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (217).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (218).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (219).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (22).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (220).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (221).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (222).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (223).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (224).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (225).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (226).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (227).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (228).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (229).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (23).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (230).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (231).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (232).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (233).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (234).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (235).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (236).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (237).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (238).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (239).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (24).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (240).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (241).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (242).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (243).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (244).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (245).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (246).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (247).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (248).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (249).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (25).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (250).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (251).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (252).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (253).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (254).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (255).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (256).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (257).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (258).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (259).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (26).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (260).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (261).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (262).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (263).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (264).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (265).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (266).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (267).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (268).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (269).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (27).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (270).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (271).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (272).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (273).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (274).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (275).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (276).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (277).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (278).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (279).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (28).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (280).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (281).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (282).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (283).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (284).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (285).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (286).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (287).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (288).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (289).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (29).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (290).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (291).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (292).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (293).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (294).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (295).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (296).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (297).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (298).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (299).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (3).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (30).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (300).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (301).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (302).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (303).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (304).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (305).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (306).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (307).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (308).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (309).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (31).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (310).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (311).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (312).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (313).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (314).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (315).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (316).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (317).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (318).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (319).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (32).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (320).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (321).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (322).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (323).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (324).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (325).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (326).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (327).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (328).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (329).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (33).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (330).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (331).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (332).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (333).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (334).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (335).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (336).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (337).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (338).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (339).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (34).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (340).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (341).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (342).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (343).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (344).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (345).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (346).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (347).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (348).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (349).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (35).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (350).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (351).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (352).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (353).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (354).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (355).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (356).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (357).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (358).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (359).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (36).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (360).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (361).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (362).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (363).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (364).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (365).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (366).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (367).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (368).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (369).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (37).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (370).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (371).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (372).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (373).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (374).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (375).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (376).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (377).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (378).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (379).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (38).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (380).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (381).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (382).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (383).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (384).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (385).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (386).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (387).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (388).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (389).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (39).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (390).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (391).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (392).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (393).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (394).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (395).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (396).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (397).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (398).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (399).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (4).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (40).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (400).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (401).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (402).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (403).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (404).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (405).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (406).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (407).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (408).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (409).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (41).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (410).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (411).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (412).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (413).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (414).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (415).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (416).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (417).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (418).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (419).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (42).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (420).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (421).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (422).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (423).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (424).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (425).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (426).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (427).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (428).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (429).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (43).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (430).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (431).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (432).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (433).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (434).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (435).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (436).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (437).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (438).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (439).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (44).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (440).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (441).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (442).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (443).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (444).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (445).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (446).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (447).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (448).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (449).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (45).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (450).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (451).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (452).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (453).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (454).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (455).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (456).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (457).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (458).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (459).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (46).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (460).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (461).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (462).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (463).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (464).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (465).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (466).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (467).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (468).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (469).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (47).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (470).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (471).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (472).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (473).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (474).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (475).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (476).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (477).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (478).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (479).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (48).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (480).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (481).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (482).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (483).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (484).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (485).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (486).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (487).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (488).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (489).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (49).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (490).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (491).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (492).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (493).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (494).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (495).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (496).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (497).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (498).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (499).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (5).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (50).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (500).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (501).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (502).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (503).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (504).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (505).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (506).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (507).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (508).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (509).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (51).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (510).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (511).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (512).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (513).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (514).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (515).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (516).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (517).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (518).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (519).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (52).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (520).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (521).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (522).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (523).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (524).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (525).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (526).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (527).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (528).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (529).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (53).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (530).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (531).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (532).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (533).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (534).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (535).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (536).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (537).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (538).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (539).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (54).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (540).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Apple_scab/image (541).JPG
# ...
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (855).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (856).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (857).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (858).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (859).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (86).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (860).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (861).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (862).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (863).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (864).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (865).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (866).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (867).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (868).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (869).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (87).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (870).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (871).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (872).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (873).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (874).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (875).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (876).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (877).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (878).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (879).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (88).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (880).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (881).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (882).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (883).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (884).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (885).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (886).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (887).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (888).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (889).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (89).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (890).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (891).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (892).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (893).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (894).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (895).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (896).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (897).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (898).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (899).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (9).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (90).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (900).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (901).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (902).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (903).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (904).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (905).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (906).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (907).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (908).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (909).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (91).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (910).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (911).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (912).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (913).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (914).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (915).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (916).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (917).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (918).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (919).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (92).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (920).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (921).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (922).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (923).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (924).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (925).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (926).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (927).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (928).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (929).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (93).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (930).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (931).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (932).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (933).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (934).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (935).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (936).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (937).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (938).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (939).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (94).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (940).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (941).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (942).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (943).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (944).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (945).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (946).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (947).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (948).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (949).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (95).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (950).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (951).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (952).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (953).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (954).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (955).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (956).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (957).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (958).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (959).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (96).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (960).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (961).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (962).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (963).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (964).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (965).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (966).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (967).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (968).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (969).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (97).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (970).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (971).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (972).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (973).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (974).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (975).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (976).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (977).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (978).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (979).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (98).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (980).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (981).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (982).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (983).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (984).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (985).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (986).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (987).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (988).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (989).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (99).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (990).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (991).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (992).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (993).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (994).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (995).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (996).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (997).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (998).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Black_rot/image (999).JPG
#    creating: Plant_leave_diseases_dataset_with_augmentation/Apple___Cedar_apple_rust/
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Cedar_apple_rust/image (1).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Cedar_apple_rust/image (10).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Cedar_apple_rust/image (100).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Cedar_apple_rust/image (1000).JPG
#   inflating: Plant_leave_diseases_dataset_with_augmentation/Apple___Cedar_apple_rust/image (101).JPG

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

# %%
# !pip install split-folders

# %%
import splitfolders
splitfolders.ratio('/content/Plant_leave_diseases_dataset_with_augmentation', output="dataset", seed=1337, ratio=(.8, .1,.1))

# %% [markdown]
# ## **Data Preprocessing**

# %%
train_dir = "/content/dataset/train"
validation_dir = "/content/dataset/val"

BATCH_SIZE = 32
IMG_SIZE = (160, 160)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
test_dir = "/content/dataset/test"
test_dataset = tf.keras.utils.image_dataset_from_directory(test_dir,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
class_names
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Background_without_leaves',
#  'Blueberry___healthy',
#  'Cherry___Powdery_mildew',
#  'Cherry___healthy',
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn___Common_rust',
#  'Corn___Northern_Leaf_Blight',
#  'Corn___healthy',
#  'Grape___Black_rot',
#  'Grape___Esca_(Black_Measles)',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Peach___Bacterial_spot',
#  'Peach___healthy',
#  'Pepper,_bell___Bacterial_spot',
#  'Pepper,_bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Raspberry___healthy',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Strawberry___Leaf_scorch',
#  'Strawberry___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
preprocess_input = tf.keras.applications.efficientnet.preprocess_input

# %% [markdown]
# ## **Create the base model from the pre-trained convnets**

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.EfficientNetB4(
    input_shape=IMG_SHAPE,
    include_top=False,
    weights='imagenet',
)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 5, 5, 1792)

# %% [markdown]
# ## **Feature extraction**
# **Freeze the convolutional base**

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "efficientnetb4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 160, 160, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_4 (Rescaling)   │ (None, 160, 160, 3)    │              0 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization_2           │ (None, 160, 160, 3)    │              7 │ rescaling_4[0][0]      │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_5 (Rescaling)   │ (None, 160, 160, 3)    │              0 │ normalization_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv_pad             │ (None, 161, 161, 3)    │              0 │ rescaling_5[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 80, 80, 48)     │          1,296 │ stem_conv_pad[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 80, 80, 48)     │            192 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 80, 80, 48)     │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_dwconv            │ (None, 80, 80, 48)     │            432 │ stem_activation[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_bn                │ (None, 80, 80, 48)     │            192 │ block1a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_activation        │ (None, 80, 80, 48)     │              0 │ block1a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_squeeze        │ (None, 48)             │              0 │ block1a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reshape        │ (None, 1, 1, 48)       │              0 │ block1a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reduce         │ (None, 1, 1, 12)       │            588 │ block1a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_expand         │ (None, 1, 1, 48)       │            624 │ block1a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_excite         │ (None, 80, 80, 48)     │              0 │ block1a_activation[0]… │
# │ (Multiply)                │                        │                │ block1a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 80, 80, 24)     │          1,152 │ block1a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 80, 80, 24)     │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_dwconv            │ (None, 80, 80, 24)     │            216 │ block1a_project_bn[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_bn                │ (None, 80, 80, 24)     │             96 │ block1b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_activation        │ (None, 80, 80, 24)     │              0 │ block1b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_squeeze        │ (None, 24)             │              0 │ block1b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reshape        │ (None, 1, 1, 24)       │              0 │ block1b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reduce         │ (None, 1, 1, 6)        │            150 │ block1b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_expand         │ (None, 1, 1, 24)       │            168 │ block1b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_excite         │ (None, 80, 80, 24)     │              0 │ block1b_activation[0]… │
# │ (Multiply)                │                        │                │ block1b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 80, 80, 24)     │            576 │ block1b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 80, 80, 24)     │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 80, 80, 24)     │              0 │ block1b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 80, 80, 24)     │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 80, 80, 144)    │          3,456 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 80, 80, 144)    │            576 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 80, 80, 144)    │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv_pad        │ (None, 81, 81, 144)    │              0 │ block2a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv            │ (None, 40, 40, 144)    │          1,296 │ block2a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_bn                │ (None, 40, 40, 144)    │            576 │ block2a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_activation        │ (None, 40, 40, 144)    │              0 │ block2a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_squeeze        │ (None, 144)            │              0 │ block2a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_excite         │ (None, 40, 40, 144)    │              0 │ block2a_activation[0]… │
# │ (Multiply)                │                        │                │ block2a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 40, 40, 32)     │          4,608 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 40, 40, 32)     │            128 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 40, 40, 192)    │          6,144 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 40, 40, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 40, 40, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 40, 40, 192)    │          1,728 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 40, 40, 192)    │            768 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 40, 40, 192)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 192)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 40, 40, 192)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 40, 40, 32)     │          6,144 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 40, 40, 32)     │            128 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 40, 40, 32)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 40, 40, 32)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 40, 40, 192)    │          6,144 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 40, 40, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 40, 40, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_dwconv            │ (None, 40, 40, 192)    │          1,728 │ block2c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_bn                │ (None, 40, 40, 192)    │            768 │ block2c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_activation        │ (None, 40, 40, 192)    │              0 │ block2c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_squeeze        │ (None, 192)            │              0 │ block2c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_excite         │ (None, 40, 40, 192)    │              0 │ block2c_activation[0]… │
# │ (Multiply)                │                        │                │ block2c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 40, 40, 32)     │          6,144 │ block2c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 40, 40, 32)     │            128 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 40, 40, 32)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 40, 40, 32)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_conv       │ (None, 40, 40, 192)    │          6,144 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_bn         │ (None, 40, 40, 192)    │            768 │ block2d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_activation │ (None, 40, 40, 192)    │              0 │ block2d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_dwconv            │ (None, 40, 40, 192)    │          1,728 │ block2d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_bn                │ (None, 40, 40, 192)    │            768 │ block2d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_activation        │ (None, 40, 40, 192)    │              0 │ block2d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_squeeze        │ (None, 192)            │              0 │ block2d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_excite         │ (None, 40, 40, 192)    │              0 │ block2d_activation[0]… │
# │ (Multiply)                │                        │                │ block2d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_conv      │ (None, 40, 40, 32)     │          6,144 │ block2d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_bn        │ (None, 40, 40, 32)     │            128 │ block2d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_drop (Dropout)    │ (None, 40, 40, 32)     │              0 │ block2d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_add (Add)         │ (None, 40, 40, 32)     │              0 │ block2d_drop[0][0],    │
# │                           │                        │                │ block2c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 40, 40, 192)    │          6,144 │ block2d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 40, 40, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 40, 40, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv_pad        │ (None, 43, 43, 192)    │              0 │ block3a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv            │ (None, 20, 20, 192)    │          4,800 │ block3a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_bn                │ (None, 20, 20, 192)    │            768 │ block3a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_activation        │ (None, 20, 20, 192)    │              0 │ block3a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_squeeze        │ (None, 192)            │              0 │ block3a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reshape        │ (None, 1, 1, 192)      │              0 │ block3a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block3a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block3a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_excite         │ (None, 20, 20, 192)    │              0 │ block3a_activation[0]… │
# │ (Multiply)                │                        │                │ block3a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 20, 20, 56)     │         10,752 │ block3a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 20, 20, 56)     │            224 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 20, 20, 336)    │         18,816 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 20, 20, 336)    │          1,344 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 20, 20, 336)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_dwconv            │ (None, 20, 20, 336)    │          8,400 │ block3b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_bn                │ (None, 20, 20, 336)    │          1,344 │ block3b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_activation        │ (None, 20, 20, 336)    │              0 │ block3b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_squeeze        │ (None, 336)            │              0 │ block3b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reshape        │ (None, 1, 1, 336)      │              0 │ block3b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block3b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block3b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_excite         │ (None, 20, 20, 336)    │              0 │ block3b_activation[0]… │
# │ (Multiply)                │                        │                │ block3b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 20, 20, 56)     │         18,816 │ block3b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 20, 20, 56)     │            224 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 20, 20, 56)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 20, 20, 56)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 20, 20, 336)    │         18,816 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 20, 20, 336)    │          1,344 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 20, 20, 336)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_dwconv            │ (None, 20, 20, 336)    │          8,400 │ block3c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_bn                │ (None, 20, 20, 336)    │          1,344 │ block3c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_activation        │ (None, 20, 20, 336)    │              0 │ block3c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_squeeze        │ (None, 336)            │              0 │ block3c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reshape        │ (None, 1, 1, 336)      │              0 │ block3c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block3c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block3c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_excite         │ (None, 20, 20, 336)    │              0 │ block3c_activation[0]… │
# │ (Multiply)                │                        │                │ block3c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 20, 20, 56)     │         18,816 │ block3c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 20, 20, 56)     │            224 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 20, 20, 56)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 20, 20, 56)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_conv       │ (None, 20, 20, 336)    │         18,816 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_bn         │ (None, 20, 20, 336)    │          1,344 │ block3d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_activation │ (None, 20, 20, 336)    │              0 │ block3d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_dwconv            │ (None, 20, 20, 336)    │          8,400 │ block3d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_bn                │ (None, 20, 20, 336)    │          1,344 │ block3d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_activation        │ (None, 20, 20, 336)    │              0 │ block3d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_squeeze        │ (None, 336)            │              0 │ block3d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_reshape        │ (None, 1, 1, 336)      │              0 │ block3d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block3d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block3d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_excite         │ (None, 20, 20, 336)    │              0 │ block3d_activation[0]… │
# │ (Multiply)                │                        │                │ block3d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_conv      │ (None, 20, 20, 56)     │         18,816 │ block3d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_bn        │ (None, 20, 20, 56)     │            224 │ block3d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_drop (Dropout)    │ (None, 20, 20, 56)     │              0 │ block3d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_add (Add)         │ (None, 20, 20, 56)     │              0 │ block3d_drop[0][0],    │
# │                           │                        │                │ block3c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 20, 20, 336)    │         18,816 │ block3d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 20, 20, 336)    │          1,344 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 20, 20, 336)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv_pad        │ (None, 21, 21, 336)    │              0 │ block4a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv            │ (None, 10, 10, 336)    │          3,024 │ block4a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 10, 10, 336)    │          1,344 │ block4a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 10, 10, 336)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 336)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 336)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 10, 10, 336)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 10, 10, 112)    │         37,632 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 10, 10, 112)    │            448 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 10, 10, 672)    │         75,264 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 10, 10, 672)    │          2,688 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 10, 10, 672)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv            │ (None, 10, 10, 672)    │          6,048 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 10, 10, 672)    │          2,688 │ block4b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_se_squeeze        │ (None, 1632)           │              0 │ block6g_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_se_reshape        │ (None, 1, 1, 1632)     │              0 │ block6g_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_se_reduce         │ (None, 1, 1, 68)       │        111,044 │ block6g_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_se_expand         │ (None, 1, 1, 1632)     │        112,608 │ block6g_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_se_excite         │ (None, 5, 5, 1632)     │              0 │ block6g_activation[0]… │
# │ (Multiply)                │                        │                │ block6g_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_project_conv      │ (None, 5, 5, 272)      │        443,904 │ block6g_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_project_bn        │ (None, 5, 5, 272)      │          1,088 │ block6g_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_drop (Dropout)    │ (None, 5, 5, 272)      │              0 │ block6g_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6g_add (Add)         │ (None, 5, 5, 272)      │              0 │ block6g_drop[0][0],    │
# │                           │                        │                │ block6f_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_expand_conv       │ (None, 5, 5, 1632)     │        443,904 │ block6g_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_expand_bn         │ (None, 5, 5, 1632)     │          6,528 │ block6h_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_expand_activation │ (None, 5, 5, 1632)     │              0 │ block6h_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_dwconv            │ (None, 5, 5, 1632)     │         40,800 │ block6h_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_bn                │ (None, 5, 5, 1632)     │          6,528 │ block6h_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_activation        │ (None, 5, 5, 1632)     │              0 │ block6h_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_se_squeeze        │ (None, 1632)           │              0 │ block6h_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_se_reshape        │ (None, 1, 1, 1632)     │              0 │ block6h_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_se_reduce         │ (None, 1, 1, 68)       │        111,044 │ block6h_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_se_expand         │ (None, 1, 1, 1632)     │        112,608 │ block6h_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_se_excite         │ (None, 5, 5, 1632)     │              0 │ block6h_activation[0]… │
# │ (Multiply)                │                        │                │ block6h_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_project_conv      │ (None, 5, 5, 272)      │        443,904 │ block6h_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_project_bn        │ (None, 5, 5, 272)      │          1,088 │ block6h_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_drop (Dropout)    │ (None, 5, 5, 272)      │              0 │ block6h_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6h_add (Add)         │ (None, 5, 5, 272)      │              0 │ block6h_drop[0][0],    │
# │                           │                        │                │ block6g_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_conv       │ (None, 5, 5, 1632)     │        443,904 │ block6h_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_bn         │ (None, 5, 5, 1632)     │          6,528 │ block7a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_activation │ (None, 5, 5, 1632)     │              0 │ block7a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_dwconv            │ (None, 5, 5, 1632)     │         14,688 │ block7a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_bn                │ (None, 5, 5, 1632)     │          6,528 │ block7a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_activation        │ (None, 5, 5, 1632)     │              0 │ block7a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_squeeze        │ (None, 1632)           │              0 │ block7a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reshape        │ (None, 1, 1, 1632)     │              0 │ block7a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reduce         │ (None, 1, 1, 68)       │        111,044 │ block7a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_expand         │ (None, 1, 1, 1632)     │        112,608 │ block7a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_excite         │ (None, 5, 5, 1632)     │              0 │ block7a_activation[0]… │
# │ (Multiply)                │                        │                │ block7a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_conv      │ (None, 5, 5, 448)      │        731,136 │ block7a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_bn        │ (None, 5, 5, 448)      │          1,792 │ block7a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_conv       │ (None, 5, 5, 2688)     │      1,204,224 │ block7a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_bn         │ (None, 5, 5, 2688)     │         10,752 │ block7b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_activation │ (None, 5, 5, 2688)     │              0 │ block7b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_dwconv            │ (None, 5, 5, 2688)     │         24,192 │ block7b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_bn                │ (None, 5, 5, 2688)     │         10,752 │ block7b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_activation        │ (None, 5, 5, 2688)     │              0 │ block7b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_squeeze        │ (None, 2688)           │              0 │ block7b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reshape        │ (None, 1, 1, 2688)     │              0 │ block7b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reduce         │ (None, 1, 1, 112)      │        301,168 │ block7b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_expand         │ (None, 1, 1, 2688)     │        303,744 │ block7b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_excite         │ (None, 5, 5, 2688)     │              0 │ block7b_activation[0]… │
# │ (Multiply)                │                        │                │ block7b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_conv      │ (None, 5, 5, 448)      │      1,204,224 │ block7b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_bn        │ (None, 5, 5, 448)      │          1,792 │ block7b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_drop (Dropout)    │ (None, 5, 5, 448)      │              0 │ block7b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_add (Add)         │ (None, 5, 5, 448)      │              0 │ block7b_drop[0][0],    │
# │                           │                        │                │ block7a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 5, 5, 1792)     │        802,816 │ block7b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 5, 5, 1792)     │          7,168 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 5, 5, 1792)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 17,673,823 (67.42 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 17,673,823 (67.42 MB)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1792)

# %%
prediction_layer = tf.keras.layers.Dense(len(class_names), activation='sigmoid')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 39)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = preprocess_input(inputs)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 160, 160, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb4 (Functional)          │ (None, 5, 5, 1792)          │      17,673,823 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1792)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1792)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 39)                  │          69,927 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,743,750 (67.69 MB)
#  Trainable params: 69,927 (273.15 KB)
#  Non-trainable params: 17,673,823 (67.42 MB)

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')])

# %%
initial_epochs = 6

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.0184 - loss: 3.7205

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 3.72
# initial accuracy: 0.02

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/6
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 156s 77ms/step - accuracy: 0.6928 - loss: 1.2347 - val_accuracy: 0.9060 - val_loss: 0.3458
# Epoch 2/6
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 103s 65ms/step - accuracy: 0.8957 - loss: 0.3725 - val_accuracy: 0.9280 - val_loss: 0.2492
# Epoch 3/6
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 142s 65ms/step - accuracy: 0.9184 - loss: 0.2810 - val_accuracy: 0.9355 - val_loss: 0.2124
# Epoch 4/6
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 100s 65ms/step - accuracy: 0.9255 - loss: 0.2491 - val_accuracy: 0.9410 - val_loss: 0.1906
# Epoch 5/6
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 98s 64ms/step - accuracy: 0.9293 - loss: 0.2245 - val_accuracy: 0.9456 - val_loss: 0.1731
# Epoch 6/6
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 143s 64ms/step - accuracy: 0.9349 - loss: 0.2062 - val_accuracy: 0.9464 - val_loss: 0.1626

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## **Fine tuning**

# %%
base_model.trainable = True

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  475

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')])

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 160, 160, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb4 (Functional)          │ (None, 5, 5, 1792)          │      17,673,823 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1792)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1792)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 39)                  │          69,927 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,743,750 (67.69 MB)
#  Trainable params: 17,531,783 (66.88 MB)
#  Non-trainable params: 211,967 (828.00 KB)

# %%
len(model.trainable_variables)
# Out:
# 333

# %%
fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=len(history.epoch),
                         validation_data=validation_dataset)
# Out:
# Epoch 7/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 469s 229ms/step - accuracy: 0.8891 - loss: 0.3985 - val_accuracy: 0.9469 - val_loss: 0.1673
# Epoch 8/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 282s 164ms/step - accuracy: 0.9608 - loss: 0.1067 - val_accuracy: 0.9749 - val_loss: 0.0561
# Epoch 9/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 261s 163ms/step - accuracy: 0.9695 - loss: 0.0758 - val_accuracy: 0.9247 - val_loss: 0.1206
# Epoch 10/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 261s 162ms/step - accuracy: 0.9645 - loss: 0.0675 - val_accuracy: 0.9464 - val_loss: 0.1105
# Epoch 11/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 263s 163ms/step - accuracy: 0.9710 - loss: 0.0591 - val_accuracy: 0.9708 - val_loss: 0.0548
# Epoch 12/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 261s 162ms/step - accuracy: 0.9744 - loss: 0.0476 - val_accuracy: 0.9474 - val_loss: 0.5304
# Epoch 13/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 263s 163ms/step - accuracy: 0.9700 - loss: 0.0372 - val_accuracy: 0.9528 - val_loss: 0.0788
# Epoch 14/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 263s 164ms/step - accuracy: 0.9718 - loss: 0.0376 - val_accuracy: 0.9438 - val_loss: 0.0993
# Epoch 15/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 260s 162ms/step - accuracy: 0.9743 - loss: 0.0299 - val_accuracy: 0.9523 - val_loss: 0.1623
# Epoch 16/16
# 1537/1537 ━━━━━━━━━━━━━━━━━━━━ 261s 162ms/step - accuracy: 0.9751 - loss: 0.0308 - val_accuracy: 0.9642 - val_loss: 0.0736

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.9651 - loss: 0.0604
# Test accuracy : 0.9644941687583923

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
predictions = tf.argmax(predictions,axis=1)

print('Predictions:\n', predictions.numpy())
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title(class_names[predictions[i]])
  plt.axis("off")
# Out:
# Predictions:
#  [35 26 17 19  1 33 11 29 29 13 26  9 26 25 35  0  0 16 24  9 29 35  9 12
#  14  6  2 33 21 16  1 14]
# Labels:
#  [35 26 17 19  1 33 11 29 29 13 26  9 28 25 35  0  0 16 24  9 29 35  9 12
#  14  6  2 33 21 16  1 14]

# %% [markdown]
# ## **Saving Model**

# %%
model.save("plant_disease_recog_model_pwp.keras")

# %%
model.save("/content/drive/MyDrive/plant_disease_recog_model_pwp.keras")
